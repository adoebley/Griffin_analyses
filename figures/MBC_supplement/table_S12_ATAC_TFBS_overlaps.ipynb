# %%
import pandas as pd
import numpy as np
import os
import time
import pybedtools
pybedtools.set_tempdir('tmp')

# %%
in_files = {'ER_positive_non_hematopoietic':'../../sites/TCGA_ATAC/ER_differential/sites_by_qval/ER_pos_specific.5e-4_qval.DESeq2.txt',
          'ER_positive_hematopoietic':'../../sites/TCGA_ATAC/ER_differential/sites_by_qval/ER_pos_heme.5e-4_qval.DESeq2.txt',
          'ER_negative_non_hematopoietic':'../../sites/TCGA_ATAC/ER_differential/sites_by_qval/ER_neg_specific.5e-4_qval.DESeq2.txt',
          'ER_negative_hematopoietic':'../../sites/TCGA_ATAC/ER_differential/sites_by_qval/ER_neg_heme.5e-4_qval.DESeq2.txt'}

GTRD_dir = '../../sites/TFBS/10000_unfiltered_sites_CIS_BP_v2/'

# %%
length_dict = {}
for key in in_files.keys():
    data = pd.read_csv(in_files[key], sep='\t')
    print(key,len(data))
    length_dict[key]=len(data)
# Out:
# ER_positive_non_hematopoietic 18240
# ER_positive_hematopoietic 9930
# ER_negative_non_hematopoietic 19347
# ER_negative_hematopoietic 22365

# %%
out_df = pd.DataFrame(columns = ['site_list','GTRD','overlaps'])
start_time = time.time()

for key in in_files.keys():
    data = pd.read_csv(in_files[key], sep='\t')
    bed_data = pybedtools.BedTool.from_dataframe(data[['Chrom','Start','End']])
    for i,file in enumerate(sorted(os.listdir(GTRD_dir))):
        GTRD_data = pd.read_csv(GTRD_dir+file, sep='\t')
        GTRD_data['new_start'] = GTRD_data['position']-250
        GTRD_data['new_end'] = GTRD_data['position']+250
        bed_GTRD = pybedtools.BedTool.from_dataframe(GTRD_data[['Chrom','new_start','new_end']])
        intersection = bed_data.intersect(bed_GTRD, u = True)
        out_df = out_df.append({'site_list':key,'GTRD':file,'overlaps':len(intersection)}, ignore_index=True)
        if i%100==0:
            print(i, np.round(time.time()-start_time,2), key,file,len(intersection))
            
    pybedtools.cleanup(remove_all=True)

#reformat
out_df = out_df.set_index(['GTRD','site_list']).unstack()

new_columns = []
for column in out_df.columns:
    new_columns.append(column[1])
out_df.columns = new_columns

#add number of sites to the column names
col_name_dict = {}

for key in in_files.keys():
    col_name_dict[key]=key+'_'+str(length_dict[key])+'_sites'
out_df = out_df.rename(columns = col_name_dict)
# Out:
# 0 0.21 ER_positive_non_hematopoietic AHR.hg38.10000.txt 1722
# 100 10.08 ER_positive_non_hematopoietic HIF3A.hg38.10000.txt 610
# 200 20.01 ER_positive_non_hematopoietic OTX2.hg38.10000.txt 127
# 300 29.81 ER_positive_non_hematopoietic TLX1.hg38.10000.txt 40
# 0 39.19 ER_positive_hematopoietic AHR.hg38.10000.txt 1021
# 100 48.65 ER_positive_hematopoietic HIF3A.hg38.10000.txt 390
# 200 58.38 ER_positive_hematopoietic OTX2.hg38.10000.txt 80
# 300 67.83 ER_positive_hematopoietic TLX1.hg38.10000.txt 208
# 0 77.47 ER_negative_non_hematopoietic AHR.hg38.10000.txt 211
# 100 87.29 ER_negative_non_hematopoietic HIF3A.hg38.10000.txt 345
# 200 97.21 ER_negative_non_hematopoietic OTX2.hg38.10000.txt 185
# 300 107.07 ER_negative_non_hematopoietic TLX1.hg38.10000.txt 81
# 0 116.78 ER_negative_hematopoietic AHR.hg38.10000.txt 292
# 100 126.97 ER_negative_hematopoietic HIF3A.hg38.10000.txt 648
# 200 137.16 ER_negative_hematopoietic OTX2.hg38.10000.txt 269
# 300 147.32 ER_negative_hematopoietic TLX1.hg38.10000.txt 482

# %%
out_df
# Out:
#                        ER_negative_hematopoietic_22365_sites  \
# GTRD
# AHR.hg38.10000.txt                                       292
# AR.hg38.10000.txt                                        124
# ARID3A.hg38.10000.txt                                    452
# ARNT.hg38.10000.txt                                      568
# ARNTL.hg38.10000.txt                                     598
# ...                                                      ...
# ZNF792.hg38.10000.txt                                    624
# ZSCAN16.hg38.10000.txt                                   246
# ZSCAN22.hg38.10000.txt                                   725
# ZSCAN4.hg38.10000.txt                                    343
# ZSCAN9.hg38.10000.txt                                    633
#
#                        ER_negative_non_hematopoietic_19347_sites  \
# GTRD
# AHR.hg38.10000.txt                                           211
# AR.hg38.10000.txt                                            117
# ARID3A.hg38.10000.txt                                        196
# ARNT.hg38.10000.txt                                          197
# ARNTL.hg38.10000.txt                                         441
# ...                                                          ...
# ZNF792.hg38.10000.txt                                        243
# ZSCAN16.hg38.10000.txt                                       109
# ZSCAN22.hg38.10000.txt                                       261
# ZSCAN4.hg38.10000.txt                                        120
# ZSCAN9.hg38.10000.txt                                        232
#
#                        ER_positive_hematopoietic_9930_sites  \
# GTRD
# AHR.hg38.10000.txt                                     1021
# AR.hg38.10000.txt                                       817
# ARID3A.hg38.10000.txt                                   353
# ARNT.hg38.10000.txt                                     340
# ARNTL.hg38.10000.txt                                     94
# ...                                                     ...
# ZNF792.hg38.10000.txt                                   377
# ZSCAN16.hg38.10000.txt                                   95
# ZSCAN22.hg38.10000.txt                                  132
# ZSCAN4.hg38.10000.txt                                   145
# ZSCAN9.hg38.10000.txt                                   382
#
#                        ER_positive_non_hematopoietic_18240_sites
# GTRD
# AHR.hg38.10000.txt                                          1722
# AR.hg38.10000.txt                                           1879
# ARID3A.hg38.10000.txt                                        394
# ARNT.hg38.10000.txt                                          317
# ARNTL.hg38.10000.txt                                          60
# ...                                                          ...
# ZNF792.hg38.10000.txt                                        339
# ZSCAN16.hg38.10000.txt                                        87
# ZSCAN22.hg38.10000.txt                                        53
# ZSCAN4.hg38.10000.txt                                        125
# ZSCAN9.hg38.10000.txt                                        399
#
# [377 rows x 4 columns]

# %%
#reformat and export
to_export = out_df.copy()
to_export.index = to_export.index.str.split('.hg38.10000', expand=True).droplevel(1)
to_export.index.name = 'TF_name'
to_export[['ER_positive_non_hematopoietic_18240_sites',
    'ER_positive_hematopoietic_9930_sites',
    'ER_negative_non_hematopoietic_19347_sites',
    'ER_negative_hematopoietic_22365_sites']].to_csv('files/S12_ATAC_TFBS_overlaps.tsv',sep='\t')

# %%
for column in out_df.columns:
    print(column)
    display(out_df.sort_values(by=column, ascending = False))
    
    print('\n')
# Out:
# ER_negative_hematopoietic_22365_sites
#                       ER_negative_hematopoietic_22365_sites  \
# GTRD
# KDM2B.hg38.10000.txt                                   1302
# NFKB1.hg38.10000.txt                                   1208
# CTCF.hg38.10000.txt                                    1203
# RELA.hg38.10000.txt                                    1174
# KMT2A.hg38.10000.txt                                   1140
# ...                                                     ...
# DUX4.hg38.10000.txt                                      78
# PHOX2B.hg38.10000.txt                                    71
# HMGA1.hg38.10000.txt                                     23
# ZNF486.hg38.10000.txt                                    21
# ZNF146.hg38.10000.txt                                    20
#
#                       ER_negative_non_hematopoietic_19347_sites  \
# GTRD
# KDM2B.hg38.10000.txt                                        266
# NFKB1.hg38.10000.txt                                        631
# CTCF.hg38.10000.txt                                          95
# RELA.hg38.10000.txt                                         395
# KMT2A.hg38.10000.txt                                        288
# ...                                                         ...
# DUX4.hg38.10000.txt                                          77
# PHOX2B.hg38.10000.txt                                        45
# HMGA1.hg38.10000.txt                                         38
# ZNF486.hg38.10000.txt                                        37
# ZNF146.hg38.10000.txt                                        14
#
#                       ER_positive_hematopoietic_9930_sites  \
# GTRD
# KDM2B.hg38.10000.txt                                    75
# NFKB1.hg38.10000.txt                                   128
# CTCF.hg38.10000.txt                                    119
# RELA.hg38.10000.txt                                    127
# KMT2A.hg38.10000.txt                                    30
# ...                                                    ...
# DUX4.hg38.10000.txt                                     38
# PHOX2B.hg38.10000.txt                                   47
# HMGA1.hg38.10000.txt                                    15
# ZNF486.hg38.10000.txt                                   17
# ZNF146.hg38.10000.txt                                   16
#
#                       ER_positive_non_hematopoietic_18240_sites
# GTRD
# KDM2B.hg38.10000.txt                                          8
# NFKB1.hg38.10000.txt                                         82
# CTCF.hg38.10000.txt                                           3
# RELA.hg38.10000.txt                                          40
# KMT2A.hg38.10000.txt                                          5
# ...                                                         ...
# DUX4.hg38.10000.txt                                          65
# PHOX2B.hg38.10000.txt                                       109
# HMGA1.hg38.10000.txt                                         43
# ZNF486.hg38.10000.txt                                        29
# ZNF146.hg38.10000.txt                                        33
#
# [377 rows x 4 columns]
# ER_negative_non_hematopoietic_19347_sites
#                       ER_negative_hematopoietic_22365_sites  \
# GTRD
# GRHL2.hg38.10000.txt                                    938
# TRPS1.hg38.10000.txt                                    939
# TEAD4.hg38.10000.txt                                    839
# NFKB1.hg38.10000.txt                                   1208
# STAT3.hg38.10000.txt                                   1113
# ...                                                     ...
# ZBTB2.hg38.10000.txt                                    835
# PHOX2B.hg38.10000.txt                                    71
# HMGA1.hg38.10000.txt                                     23
# ZNF486.hg38.10000.txt                                    21
# ZNF146.hg38.10000.txt                                    20
#
#                       ER_negative_non_hematopoietic_19347_sites  \
# GTRD
# GRHL2.hg38.10000.txt                                       1013
# TRPS1.hg38.10000.txt                                        655
# TEAD4.hg38.10000.txt                                        650
# NFKB1.hg38.10000.txt                                        631
# STAT3.hg38.10000.txt                                        599
# ...                                                         ...
# ZBTB2.hg38.10000.txt                                         48
# PHOX2B.hg38.10000.txt                                        45
# HMGA1.hg38.10000.txt                                         38
# ZNF486.hg38.10000.txt                                        37
# ZNF146.hg38.10000.txt                                        14
#
#                       ER_positive_hematopoietic_9930_sites  \
# GTRD
# GRHL2.hg38.10000.txt                                   298
# TRPS1.hg38.10000.txt                                   241
# TEAD4.hg38.10000.txt                                   255
# NFKB1.hg38.10000.txt                                   128
# STAT3.hg38.10000.txt                                   186
# ...                                                    ...
# ZBTB2.hg38.10000.txt                                   155
# PHOX2B.hg38.10000.txt                                   47
# HMGA1.hg38.10000.txt                                    15
# ZNF486.hg38.10000.txt                                   17
# ZNF146.hg38.10000.txt                                   16
#
#                       ER_positive_non_hematopoietic_18240_sites
# GTRD
# GRHL2.hg38.10000.txt                                        549
# TRPS1.hg38.10000.txt                                        252
# TEAD4.hg38.10000.txt                                        218
# NFKB1.hg38.10000.txt                                         82
# STAT3.hg38.10000.txt                                        106
# ...                                                         ...
# ZBTB2.hg38.10000.txt                                         17
# PHOX2B.hg38.10000.txt                                       109
# HMGA1.hg38.10000.txt                                         43
# ZNF486.hg38.10000.txt                                        29
# ZNF146.hg38.10000.txt                                        33
#
# [377 rows x 4 columns]
# ER_positive_hematopoietic_9930_sites
#                       ER_negative_hematopoietic_22365_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                    144
# ESR1.hg38.10000.txt                                     177
# GATA3.hg38.10000.txt                                    216
# PGR.hg38.10000.txt                                      367
# AHR.hg38.10000.txt                                      292
# ...                                                     ...
# KMT2A.hg38.10000.txt                                   1140
# ZNF486.hg38.10000.txt                                    21
# ZNF146.hg38.10000.txt                                    20
# HMGA1.hg38.10000.txt                                     23
# CXXC1.hg38.10000.txt                                    763
#
#                       ER_negative_non_hematopoietic_19347_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                         80
# ESR1.hg38.10000.txt                                         110
# GATA3.hg38.10000.txt                                         75
# PGR.hg38.10000.txt                                          247
# AHR.hg38.10000.txt                                          211
# ...                                                         ...
# KMT2A.hg38.10000.txt                                        288
# ZNF486.hg38.10000.txt                                        37
# ZNF146.hg38.10000.txt                                        14
# HMGA1.hg38.10000.txt                                         38
# CXXC1.hg38.10000.txt                                        260
#
#                       ER_positive_hematopoietic_9930_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                  1369
# ESR1.hg38.10000.txt                                   1257
# GATA3.hg38.10000.txt                                  1230
# PGR.hg38.10000.txt                                    1221
# AHR.hg38.10000.txt                                    1021
# ...                                                    ...
# KMT2A.hg38.10000.txt                                    30
# ZNF486.hg38.10000.txt                                   17
# ZNF146.hg38.10000.txt                                   16
# HMGA1.hg38.10000.txt                                    15
# CXXC1.hg38.10000.txt                                     9
#
#                       ER_positive_non_hematopoietic_18240_sites
# GTRD
# FOXA1.hg38.10000.txt                                       2750
# ESR1.hg38.10000.txt                                        1949
# GATA3.hg38.10000.txt                                       1522
# PGR.hg38.10000.txt                                         1758
# AHR.hg38.10000.txt                                         1722
# ...                                                         ...
# KMT2A.hg38.10000.txt                                          5
# ZNF486.hg38.10000.txt                                        29
# ZNF146.hg38.10000.txt                                        33
# HMGA1.hg38.10000.txt                                         43
# CXXC1.hg38.10000.txt                                          6
#
# [377 rows x 4 columns]
# ER_positive_non_hematopoietic_18240_sites
#                      ER_negative_hematopoietic_22365_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                   144
# ESR1.hg38.10000.txt                                    177
# AR.hg38.10000.txt                                      124
# PGR.hg38.10000.txt                                     367
# AHR.hg38.10000.txt                                     292
# ...                                                    ...
# YY1.hg38.10000.txt                                     746
# SP1.hg38.10000.txt                                     546
# KMT2A.hg38.10000.txt                                  1140
# MAX.hg38.10000.txt                                     879
# CTCF.hg38.10000.txt                                   1203
#
#                      ER_negative_non_hematopoietic_19347_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                        80
# ESR1.hg38.10000.txt                                        110
# AR.hg38.10000.txt                                          117
# PGR.hg38.10000.txt                                         247
# AHR.hg38.10000.txt                                         211
# ...                                                        ...
# YY1.hg38.10000.txt                                         264
# SP1.hg38.10000.txt                                         306
# KMT2A.hg38.10000.txt                                       288
# MAX.hg38.10000.txt                                         277
# CTCF.hg38.10000.txt                                         95
#
#                      ER_positive_hematopoietic_9930_sites  \
# GTRD
# FOXA1.hg38.10000.txt                                 1369
# ESR1.hg38.10000.txt                                  1257
# AR.hg38.10000.txt                                     817
# PGR.hg38.10000.txt                                   1221
# AHR.hg38.10000.txt                                   1021
# ...                                                   ...
# YY1.hg38.10000.txt                                     59
# SP1.hg38.10000.txt                                     67
# KMT2A.hg38.10000.txt                                   30
# MAX.hg38.10000.txt                                     72
# CTCF.hg38.10000.txt                                   119
#
#                      ER_positive_non_hematopoietic_18240_sites
# GTRD
# FOXA1.hg38.10000.txt                                      2750
# ESR1.hg38.10000.txt                                       1949
# AR.hg38.10000.txt                                         1879
# PGR.hg38.10000.txt                                        1758
# AHR.hg38.10000.txt                                        1722
# ...                                                        ...
# YY1.hg38.10000.txt                                           5
# SP1.hg38.10000.txt                                           5
# KMT2A.hg38.10000.txt                                         5
# MAX.hg38.10000.txt                                           4
# CTCF.hg38.10000.txt                                          3
#
# [377 rows x 4 columns]
