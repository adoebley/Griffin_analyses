# %%
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
#for ipynb
# %matplotlib inline

# %%
tfx_path = '../../../metadata/delfi/analysis/Delfi_tumor_fraction_data.txt'
metadata_path = '../../../../griffin_paper/data/delfi_metadata/analysis/matched_metadata_corrected.txt'
in_dirs = ['../../TFBS_nucleosome_profiling_unfiltered_v2/results/']
correction = 'GC_corrected'
filtering = 'exclusion_filtered'

# %%
#get list of files with data

in_files = []
for in_dir in in_dirs:
    for file in os.listdir(in_dir):
        if not file == 'plots':
            in_files.append(in_dir+'/'+file+'/'+file+'.'+correction+'.coverage.tsv')
print(len(in_files))
# Out:
# 423

# %%
#get columns with coverage data
plot_columns = np.arange(-990,990,15)
str_plot_columns = [str(m) for m in plot_columns]

# %%
#import data
start_time = time.time()
data = pd.DataFrame()
for i,file in enumerate(in_files):
    if i%50==0:
        print(i,'importing',file,time.time()-start_time)
    current = pd.read_csv(file,sep='\t')
    data = data.append(current, ignore_index=True)
# Out:
# 0 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Healthy_CGPLH644/Healthy_CGPLH644.GC_corrected.coverage.tsv 0.0008962154388427734
# 50 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Breast_Cancer_CGPLBR72/Breast_Cancer_CGPLBR72.GC_corrected.coverage.tsv 2.1471381187438965
# 100 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Healthy_CGPLH316/Healthy_CGPLH316.GC_corrected.coverage.tsv 5.79936671257019
# 150 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Breast_Cancer_CGPLBR61/Breast_Cancer_CGPLBR61.GC_corrected.coverage.tsv 10.95226502418518
# 200 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Breast_Cancer_CGPLBR90/Breast_Cancer_CGPLBR90.GC_corrected.coverage.tsv 17.6791729927063
# 250 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Healthy_CGPLH443/Healthy_CGPLH443.GC_corrected.coverage.tsv 25.968024969100952
# 300 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Breast_Cancer_CGPLBR93/Breast_Cancer_CGPLBR93.GC_corrected.coverage.tsv 35.757113456726074
# 350 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Gastric_cancer_CGST13/Gastric_cancer_CGST13.GC_corrected.coverage.tsv 47.11781859397888
# 400 importing ../../TFBS_nucleosome_profiling_unfiltered_v2/results//Lung_Cancer_CGPLLU163/Lung_Cancer_CGPLLU163.GC_corrected.coverage.tsv 60.09967494010925

# %%
#get the metadata
metadata1 = pd.read_csv(metadata_path, sep='\t')
metadata1 = metadata1[['new_sample_name','Stage','Age at Diagnosis', 'Gender']].set_index('new_sample_name') 
metadata2 = pd.read_csv(tfx_path, sep='\t')
metadata2 = metadata2[['sample','tumor_fraction','sample_type']].set_index('sample') 
metadata = metadata1.merge(metadata2, left_index = True, right_index=True)
metadata = metadata.reset_index()
metadata = metadata.rename(columns = {'index':'sample'})
metadata['status'] = np.where(metadata['sample_type'].str.contains('ancer'),1,0)
metadata['Stage'] = metadata['Stage'].str.strip(' ')

metadata_columns = ['sample','tumor_fraction','status','sample_type','Stage','Age at Diagnosis', 'Gender']
metadata = metadata[metadata_columns]
print("metadata:",len(metadata))
# Out:
# metadata: 423

# %%
#merge with data
data = data.merge(metadata, on = 'sample')
print(len(data['sample'].unique()))
# Out:
# 423

# %%
data['number_of_sites'].unique()
# Out:
# array([20000, 10000,  5000,  1000])

# %%
print(len(data['site_name'].unique()))
data['site_name'].unique()[0:10]
# Out:
# 1705
# array(['AHR.hg38.20000', 'AR.hg38.20000', 'ARNT.hg38.20000',
#        'ARNTL.hg38.20000', 'ASCL1.hg38.20000', 'ASCL2.hg38.20000',
#        'ATF1.hg38.20000', 'ATF2.hg38.20000', 'ATF3.hg38.20000',
#        'ATF4.hg38.20000'], dtype=object)

# %%
#get the key columns
data = data[metadata_columns+['site_name','correction',
                              'central_coverage','amplitude','mean_coverage']+str_plot_columns]
print(len(data))

data['site_group'] = data['site_name'].str.rsplit('.',1,expand = True)[1]+'-sites'


#export only 10000 sites
group = '10000-sites'
df = data[data['site_group']==group]

print(group,len(df['site_name'].unique()))

df.to_csv('merged_data/'+group+'_data_with_features.'+correction+'.'+filtering+'.txt', sep='\t', index=False)

#reformat for logistic regression
reformatted = df[metadata_columns+['site_name','site_group','central_coverage','amplitude','mean_coverage']]
reformatted = reformatted.set_index(metadata_columns+['site_group','site_name']).unstack()
new_column_names = []
for item in reformatted.columns.values:
    new_column_names.append('_'.join(item))
reformatted.columns = new_column_names

reformatted.to_csv('merged_data/'+group+'_reformatted.'+correction+'.'+filtering+'.txt', sep='\t')

print(reformatted.shape)
# Out:
# 721215
# 10000-sites 377
# (423, 1131)

# %%
#plot
for site_name in ['SPI1','AHR']:
    current = data[data['site_name'].str.contains(site_name)][str_plot_columns].mean()
    plt.plot(plot_columns,current, label=site_name)
    plt.title(site_name)
    #plt.show()
plt.legend()

# %%
fft_columns = np.arange(-960,960,15)
str_fft_columns = [str(m) for m in fft_columns]

#plot out what the fft is doing for a given frequency
demo_res = np.fft.fft(current[str_fft_columns])
demo_signal = current[str_fft_columns]

frequency = 10
print('fft real', demo_res[frequency].real)
print('fft imag', demo_res[frequency].imag)
print('fft magn',np.abs(demo_res[frequency]))

#get angles for rotation
angles = np.linspace(0,2*np.pi,len(demo_signal)+1)
angles = -angles[0:-1]

#wrapped at frequency
heights = np.sin(angles*frequency)*demo_signal
widths = np.cos(angles*frequency)*demo_signal
fig,ax = plt.subplots(figsize = (10,10))
ax.plot(widths,heights, alpha = 0.5)
ax.scatter(widths,heights, alpha = 0.5)
ax.set_aspect('equal')
ax.scatter(sum(widths),sum(heights))
ax.axvline(0, color = 'grey')
ax.axhline(0, color = 'grey')
print('sum x coords',sum(widths))
print('sum y coords',sum(heights))
print('magnitude:',np.sqrt(sum(widths)**2+sum(heights)**2))
# Out:
# fft real -0.18477238201598664
# fft imag 0.05546764955606834
# fft magn 0.19291835916557168
# sum x coords -0.184772382016001
# sum y coords 0.05546764955604522
# magnitude: 0.19291835916557878

# %%
# from scipy.signal import find_peaks
# plt.plot(fft_columns,current)
# peaks =  [fft_columns[m] for m in find_peaks(current)[0]]
# plt.scatter(peaks,[.99 for m in peaks])
# print(peaks)

# spacing = []
# for i in range(len(peaks)-1):
#     spacing.append(peaks[i+1]-peaks[i])
# np.mean(spacing)
