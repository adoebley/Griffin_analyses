# %%
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
#for ipynb
# %matplotlib inline

# %%
#get list of files with data
in_dirs = ['../TFBS_nucleosome_profiling_1/results','../TFBS_nucleosome_profiling_30000sites/results','../TFBS_nucleosome_profiling_50000sites/results']

in_files = []
for in_dir in in_dirs:
    for file in os.listdir(in_dir):
        if not file == 'plots':
            in_files.append(in_dir+'/'+file+'/'+file+'.GC_corrected.coverage.tsv')
print(len(in_files))
# Out:
# 762

# %%
#get columns with coverage data
plot_columns = np.arange(-990,990,15)
str_plot_columns = [str(m) for m in plot_columns]

# %%
#import data
start_time = time.time()
data = pd.DataFrame()
for i,file in enumerate(in_files):
    if i%50==0:
        print(i,'importing',file,time.time()-start_time)
    current = pd.read_csv(file,sep='\t')
    data = data.append(current, ignore_index=True)
# Out:
# 0 importing ../TFBS_nucleosome_profiling_1/results/MBC_1421_3_ULP/MBC_1421_3_ULP.GC_corrected.coverage.tsv 0.0006177425384521484
# 50 importing ../TFBS_nucleosome_profiling_1/results/MBC_1167_5_ULP/MBC_1167_5_ULP.GC_corrected.coverage.tsv 2.5793426036834717
# 100 importing ../TFBS_nucleosome_profiling_1/results/MBC_1297_ULP/MBC_1297_ULP.GC_corrected.coverage.tsv 6.925545930862427
# 150 importing ../TFBS_nucleosome_profiling_1/results/MBC_1421_5_ULP/MBC_1421_5_ULP.GC_corrected.coverage.tsv 14.722212553024292
# 200 importing ../TFBS_nucleosome_profiling_1/results/MBC_1117_1_ULP/MBC_1117_1_ULP.GC_corrected.coverage.tsv 21.74404764175415
# 250 importing ../TFBS_nucleosome_profiling_1/results/MBC_1111_1_ULP/MBC_1111_1_ULP.GC_corrected.coverage.tsv 30.287854194641113
# 300 importing ../TFBS_nucleosome_profiling_30000sites/results/MBC_1119_3_ULP/MBC_1119_3_ULP.GC_corrected.coverage.tsv 38.80691146850586
# 350 importing ../TFBS_nucleosome_profiling_30000sites/results/MBC_1295_2_ULP/MBC_1295_2_ULP.GC_corrected.coverage.tsv 47.501484394073486
# 400 importing ../TFBS_nucleosome_profiling_30000sites/results/MBC_1087_2_ULP/MBC_1087_2_ULP.GC_corrected.coverage.tsv 56.45683455467224
# 450 importing ../TFBS_nucleosome_profiling_30000sites/results/MBC_1117_2_ULP/MBC_1117_2_ULP.GC_corrected.coverage.tsv 65.5944333076477
# 500 importing ../TFBS_nucleosome_profiling_30000sites/results/MBC_1128_4_ULP/MBC_1128_4_ULP.GC_corrected.coverage.tsv 74.9640851020813
# 550 importing ../TFBS_nucleosome_profiling_50000sites/results/MBC_1125_1_ULP/MBC_1125_1_ULP.GC_corrected.coverage.tsv 84.52228999137878
# 600 importing ../TFBS_nucleosome_profiling_50000sites/results/MBC_1086_ULP/MBC_1086_ULP.GC_corrected.coverage.tsv 94.19646453857422
# 650 importing ../TFBS_nucleosome_profiling_50000sites/results/MBC_1052_ULP/MBC_1052_ULP.GC_corrected.coverage.tsv 104.11282157897949
# 700 importing ../TFBS_nucleosome_profiling_50000sites/results/MBC_1107_2_ULP/MBC_1107_2_ULP.GC_corrected.coverage.tsv 114.2235517501831
# 750 importing ../TFBS_nucleosome_profiling_50000sites/results/MBC_1306_4_ULP/MBC_1306_4_ULP.GC_corrected.coverage.tsv 124.57949995994568

# %%
#get the subtype data
subtype_data = pd.read_csv('../../metadata/MBC/merged_tables_revisions1/merged_key_metadata.txt', sep='\t')
metadata_columns = ['sample','patient_id','revisions_ER_status_binary','ulp_wgs_coverage','tumor_fraction','first_passing_sample']
subtype_data = subtype_data[metadata_columns]

#merge with data
print(len(data))
data = data.merge(subtype_data, on = 'sample')
print(len(data['sample'].unique()))
# Out:
# 552958
# 254

# %%
data['number_of_sites'].unique()
# Out:
# array([20000, 10000,  5000,  1000, 30000, 50000])

# %%
print(len(data['site_name'].unique()))
data['site_name'].unique()
# Out:
# 2177
# array(['AHR.hg38.20000', 'AR.hg38.20000', 'ARNT.hg38.20000', ...,
#        'ZNF384.hg38.50000', 'ZNF449.hg38.50000', 'ZNF770.hg38.50000'],
#       dtype=object)

# %%
#get the key columns
data = data[metadata_columns+['site_name','correction',
                              'central_coverage','amplitude','mean_coverage']+str_plot_columns]
print(len(data))

data['site_group'] = data['site_name'].str.rsplit('.',1,expand = True)[1]+'-sites'


#export each site group
for group,df in data.groupby('site_group'):
    print(group,len(df['site_name'].unique()))

    df.to_csv('merged_data/'+group+'_data_with_features.txt', sep='\t', index=False)

    #reformat for logistic regression
    reformatted = df[metadata_columns+['site_name','site_group','central_coverage','amplitude','mean_coverage']]
    reformatted = reformatted.set_index(metadata_columns+['site_group','site_name']).unstack()
    new_column_names = []
    for item in reformatted.columns.values:
        new_column_names.append('_'.join(item))
    reformatted.columns = new_column_names

    reformatted.to_csv('merged_data/'+group+'_reformatted.txt', sep='\t')

    print(reformatted.shape)
# Out:
# 552958
# 1000-sites 566
# (254, 1698)
# 10000-sites 377
# (254, 1131)
# 20000-sites 316
# (254, 948)
# 30000-sites 270
# (254, 810)
# 5000-sites 446
# (254, 1338)
# 50000-sites 202
# (254, 606)

# %%
#plot
for site_name in ['SPI1','AHR']:
    current = data[data['site_name'].str.contains(site_name)][str_plot_columns].mean()
    plt.plot(plot_columns,current, label=site_name)
    plt.title(site_name)
    #plt.show()
plt.legend()

# %%
fft_columns = np.arange(-960,960,15)
str_fft_columns = [str(m) for m in fft_columns]

#plot out what the fft is doing for a given frequency
demo_res = np.fft.fft(current[str_fft_columns])
demo_signal = current[str_fft_columns]

frequency = 10
print('fft real', demo_res[frequency].real)
print('fft imag', demo_res[frequency].imag)
print('fft magn',np.abs(demo_res[frequency]))

#get angles for rotation
angles = np.linspace(0,2*np.pi,len(demo_signal)+1)
angles = -angles[0:-1]

#wrapped at frequency
heights = np.sin(angles*frequency)*demo_signal
widths = np.cos(angles*frequency)*demo_signal
fig,ax = plt.subplots(figsize = (10,10))
ax.plot(widths,heights, alpha = 0.5)
ax.scatter(widths,heights, alpha = 0.5)
ax.set_aspect('equal')
ax.scatter(sum(widths),sum(heights))
ax.axvline(0, color = 'grey')
ax.axhline(0, color = 'grey')
print('sum x coords',sum(widths))
print('sum y coords',sum(heights))
print('magnitude:',np.sqrt(sum(widths)**2+sum(heights)**2))
# Out:
# fft real -0.25676849108276784
# fft imag 0.030120258084450745
# fft magn 0.2585290853269615
# sum x coords -0.25676849108277977
# sum y coords 0.030120258084426976
# magnitude: 0.2585290853269706

# %%
# from scipy.signal import find_peaks
# plt.plot(fft_columns,current)
# peaks =  [fft_columns[m] for m in find_peaks(current)[0]]
# plt.scatter(peaks,[.99 for m in peaks])
# print(peaks)

# spacing = []
# for i in range(len(peaks)-1):
#     spacing.append(peaks[i+1]-peaks[i])
# np.mean(spacing)
