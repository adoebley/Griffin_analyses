# %%
import pandas as pd
import numpy as np
import time
import sys
import os

# %%
data_path='../Homo_sapiens_meta_clusters.interval'

# %%
#path to directory with bed files

#minimum number of sites
number_of_sites = [1000,5000,10000,20000,30000,50000]
min_sites = min(number_of_sites)

#path to output yaml

output_name = 'unfiltered_sites_CIS_BP_v2'
out_yaml='all_'+output_name+'.yaml'

#path to cis-bp info
CIS_BP_list = '../CIS_BP/Homo_sapiens_2021_04_29_Cis-BP_v_2.00/TF_Information.txt'

# %%
#may take 2-8 minutes
#import data

start_time=time.time()

data=pd.read_csv(data_path, usecols=['#CHROM','START','END','tfTitle','uniprotId','peak.count','exp.count'],sep='\t')

print(time.time()-start_time)

#rename columns
data=data.rename(columns={'#CHROM': 'Chrom', 'START': "Start", 'END': 'End', 'tfTitle': 'Gene'}) 
#remove any rows without a gene name (these all seem to be a Tet1 splice variant with uniprot id A0A023HHK9)
data=data[~data['Gene'].isnull()] 
#replace / with - so that the file names don't have /
data['Gene']=data['Gene'].str.replace('/','-') 
data['Gene'] = data['Gene']+'.hg38'

print(time.time()-start_time)
sys.stdout.flush()
data.head()
# Out:
# 131.4678132534027
# 170.64420127868652
#   Chrom  Start    End uniprotId         Gene  exp.count  peak.count
# 0  chr1   9989  10082    Q9UBN7   HDAC6.hg38          1           2
# 1  chr1   9992  10073    Q6P4R8   NFRKB.hg38          2           4
# 2  chr1  10004  10069    Q9NUA8  ZBTB40.hg38          1           3
# 3  chr1  10020  10117    P03372    ESR1.hg38          4           5
# 4  chr1  10036  10115    O14646    CHD1.hg38          1           2

# %%
valid_TFs = pd.read_csv(CIS_BP_list, sep='\t')#['TF_Name']
valid_TFs = valid_TFs.sort_values(by = 'TF_Name')
#exclude TFs where the binding site is not known
valid_TFs = valid_TFs[valid_TFs['TF_Status']!='N']
#get just TF names
valid_TFs = pd.Series(valid_TFs['TF_Name'].unique())
valid_TFs = valid_TFs+'.hg38'

# %%
print(len(valid_TFs))
# Out:
# 1200

# %%
chroms = ['chr'+str(m) for m in range(1,23)]

# %%
output=[]
for name,df in data.groupby('Gene'):
    df = df[df['Chrom'].isin(chroms)].copy()
    if len(df)>=min_sites and name in valid_TFs.values: #if there were at least min_sites on the list and it is a real TF
        #get the top sites
        df = df.sort_values(by='peak.count', ascending=False)
        df['position'] = (np.floor((df['Start']+df['End'])/2)).astype(int)
        for i in number_of_sites:
            current = df.iloc[0:i].reset_index(drop=True)
            if len(current)==i:
                out_file = '../'+str(i)+'_'+output_name+'/'+name+'.'+str(i)+'.txt'
                output.append([name,i,out_file,len(df)])
                current.to_csv(out_file, sep='\t', index=False)
    else: 
        print(name,'\t',len(df),'\t', name in valid_TFs.values)
# Out:
# ADA2.hg38 	 1449 	 False
# ADCYAP1.hg38 	 117 	 False
# ADNP.hg38 	 6371 	 False
# AEBP2.hg38 	 2151 	 False
# AFF1.hg38 	 60016 	 False
# AFF4.hg38 	 74042 	 False
# AGO1.hg38 	 57951 	 False
# AGO2.hg38 	 31222 	 False
# AHRR.hg38 	 5073 	 False
# ALKBH3.hg38 	 606 	 False
# ALX4.hg38 	 232 	 True
# ALYREF.hg38 	 31 	 False
# AMH.hg38 	 85412 	 False
# APC.hg38 	 12604 	 False
# APOBEC3B.hg38 	 28581 	 False
# ARHGAP35.hg38 	 269 	 False
# ARID1A.hg38 	 43331 	 False
# ARID1B.hg38 	 32353 	 False
# ARID2.hg38 	 121817 	 False
# ARID4B.hg38 	 46706 	 False
# ARNT2.hg38 	 869 	 True
# ARRB1.hg38 	 13759 	 False
# ASF1A.hg38 	 10710 	 False
# ASH1L.hg38 	 1760 	 False
# ASH2L.hg38 	 16926 	 False
# ASXL2.hg38 	 489 	 False
# ATF7IP.hg38 	 47579 	 False
# ATM.hg38 	 224 	 False
# ATOH1.hg38 	 214 	 True
# ATRX.hg38 	 7119 	 False
# AUTS2.hg38 	 2021 	 False
# BAHD1.hg38 	 1923 	 False
# BANP.hg38 	 725 	 False
# BAP1.hg38 	 5411 	 False
# BATF2.hg38 	 13 	 False
# BBX.hg38 	 67 	 True
# BCHE.hg38 	 23710 	 False
# BCL3.hg38 	 89906 	 False
# BCLAF1.hg38 	 11869 	 False
# BCOR.hg38 	 29776 	 False
# BDP1.hg38 	 21143 	 False
# BHLHE41.hg38 	 24 	 True
# BICRA.hg38 	 33710 	 False
# BMI1.hg38 	 332815 	 False
# BRCA1.hg38 	 55515 	 False
# BRD1.hg38 	 9014 	 False
# BRD2.hg38 	 171111 	 False
# BRD3.hg38 	 85369 	 False
# BRD4.hg38 	 2530180 	 False
# BRD7.hg38 	 61850 	 False
# BRD9.hg38 	 207718 	 False
# BRF1.hg38 	 302 	 False
# BRF2.hg38 	 53 	 False
# BRPF3.hg38 	 33624 	 False
# CARM1.hg38 	 61 	 False
# CASP8AP2.hg38 	 923 	 False
# CASZ1.hg38 	 12358 	 False
# CAT.hg38 	 21123 	 False
# CAVIN1.hg38 	 1094 	 False
# CBFA2T2.hg38 	 20469 	 False
# CBFA2T3.hg38 	 41969 	 False
# CBFB.hg38 	 11675 	 False
# CBX1.hg38 	 24000 	 False
# CBX2.hg38 	 45460 	 False
# CBX3.hg38 	 218152 	 False
# CBX5.hg38 	 15394 	 False
# CBX6.hg38 	 12561 	 False
# CBX7.hg38 	 5559 	 False
# CBX8.hg38 	 74475 	 False
# CC2D1A.hg38 	 10120 	 False
# CCAR2.hg38 	 3057 	 False
# CCND2.hg38 	 10950 	 False
# CCNT2.hg38 	 16638 	 False
# CDC73.hg38 	 2244 	 False
# CDK12.hg38 	 20263 	 False
# CDK2.hg38 	 163954 	 False
# CDK7.hg38 	 44077 	 False
# CDK8.hg38 	 109157 	 False
# CDK9.hg38 	 345981 	 False
# CDKN1B.hg38 	 98326 	 False
# CDX1.hg38 	 286 	 True
# CEBPE.hg38 	 401 	 True
# CENPA.hg38 	 139860 	 False
# CENPT.hg38 	 101 	 False
# CGAS.hg38 	 27 	 False
# CHAF1A.hg38 	 139 	 False
# CHAF1B.hg38 	 3473 	 False
# CHAMP1.hg38 	 1983 	 False
# CHD1.hg38 	 117657 	 False
# CHD2.hg38 	 61862 	 False
# CHD4.hg38 	 66406 	 False
# CHD7.hg38 	 208200 	 False
# CHD8.hg38 	 120674 	 False
# CHTOP.hg38 	 11 	 False
# CIITA.hg38 	 1916 	 False
# CNOT3.hg38 	 129347 	 False
# COBLL1.hg38 	 1459 	 False
# COIL.hg38 	 23 	 False
# COPS2.hg38 	 5 	 False
# CPSF3.hg38 	 9897 	 False
# CREB3L2.hg38 	 227 	 True
# CREBBP.hg38 	 99217 	 False
# CREBL2.hg38 	 295 	 True
# CRY1.hg38 	 63562 	 False
# CSHL1.hg38 	 1675 	 False
# CSNK2A1.hg38 	 6488 	 False
# CTBP1.hg38 	 40938 	 False
# CTBP2.hg38 	 29273 	 False
# CTNNB1.hg38 	 2710 	 False
# CTR9.hg38 	 695 	 False
# CUL4A.hg38 	 137508 	 False
# DACH1.hg38 	 6785 	 False
# DAXX.hg38 	 57073 	 False
# DCP1A.hg38 	 26906 	 False
# DDX11.hg38 	 196 	 False
# DDX20.hg38 	 4994 	 False
# DDX21.hg38 	 3601 	 False
# DDX5.hg38 	 4685 	 False
# DEK.hg38 	 19301 	 False
# DICER1.hg38 	 333 	 False
# DIDO1.hg38 	 1958 	 False
# DKK1.hg38 	 18 	 False
# DMAP1.hg38 	 21265 	 False
# DMC1.hg38 	 29077 	 False
# DMRT1.hg38 	 10 	 True
# DNMT3A.hg38 	 4417 	 False
# DNMT3B.hg38 	 81998 	 False
# DOT1L.hg38 	 1176 	 False
# DPF2.hg38 	 196331 	 False
# DPPA3.hg38 	 120 	 False
# DRAP1.hg38 	 24128 	 False
# DROSHA.hg38 	 123 	 False
# DTL.hg38 	 175647 	 False
# DYRK1A.hg38 	 1432 	 False
# EBNA1BP2.hg38 	 3840 	 False
# EBP.hg38 	 17292 	 False
# EED.hg38 	 166092 	 False
# EGFR.hg38 	 156 	 False
# EHMT2.hg38 	 95664 	 False
# ELF2.hg38 	 788 	 True
# ELF5.hg38 	 782 	 True
# ELL2.hg38 	 32005 	 False
# EMSY.hg38 	 66478 	 False
# EP300.hg38 	 1483006 	 False
# EP400.hg38 	 64617 	 False
# EPC1.hg38 	 390 	 False
# ERCC2.hg38 	 44779 	 False
# ERCC3.hg38 	 136471 	 False
# ERCC6.hg38 	 63415 	 False
# ERCC8.hg38 	 183 	 False
# ESCO2.hg38 	 19712 	 False
# EVX1.hg38 	 19 	 True
# EWSR1.hg38 	 10743 	 False
# EZH2.hg38 	 674587 	 False
# F10.hg38 	 2742 	 False
# F2RL1.hg38 	 240 	 False
# FAM208A.hg38 	 458 	 False
# FANCD2.hg38 	 183893 	 False
# FGFR1.hg38 	 21207 	 False
# FIP1L1.hg38 	 34259 	 False
# FOXD3.hg38 	 54 	 True
# FOXF1.hg38 	 215 	 True
# FOXF2.hg38 	 217 	 True
# FOXO4.hg38 	 923 	 True
# FOXQ1.hg38 	 53 	 True
# FOXR2.hg38 	 197 	 True
# FUS.hg38 	 12721 	 False
# FXR1.hg38 	 2486 	 False
# FXR2.hg38 	 20136 	 False
# GABPB1.hg38 	 37416 	 False
# GATAD1.hg38 	 35241 	 False
# GATAD2A.hg38 	 301509 	 False
# GATAD2B.hg38 	 245005 	 False
# GLI1.hg38 	 751 	 True
# GREB1.hg38 	 10317 	 False
# GRHL3.hg38 	 113155 	 False
# GTF2A2.hg38 	 1238 	 False
# GTF2E2.hg38 	 422 	 False
# GTF2F1.hg38 	 35305 	 False
# GTF3A.hg38 	 359 	 True
# GTF3C2.hg38 	 13094 	 False
# GTF3C5.hg38 	 14918 	 False
# GUCY1B3.hg38 	 1480 	 False
# GZF1.hg38 	 206 	 True
# H2AFZ.hg38 	 259825 	 False
# HBZ.hg38 	 32448 	 False
# HCFC1.hg38 	 23237 	 False
# HDAC1.hg38 	 93622 	 False
# HDAC2.hg38 	 232833 	 False
# HDAC3.hg38 	 5063 	 False
# HDAC4.hg38 	 1844 	 False
# HDAC6.hg38 	 24273 	 False
# HDAC8.hg38 	 646 	 False
# HDGF.hg38 	 3479 	 False
# HDGFL3.hg38 	 100175 	 False
# HES4.hg38 	 616 	 True
# HES5.hg38 	 46 	 True
# HES7.hg38 	 104 	 True
# HESX1.hg38 	 3 	 True
# HEXIM1.hg38 	 104160 	 False
# HEY2.hg38 	 678 	 True
# HIC2.hg38 	 69 	 True
# HIRA.hg38 	 99889 	 False
# HIST1H1T.hg38 	 2380 	 False
# HIVEP1.hg38 	 906 	 True
# HIVEP3.hg38 	 5 	 True
# HJURP.hg38 	 91 	 False
# HMCES.hg38 	 279 	 False
# HMGA2.hg38 	 74 	 True
# HMGB1.hg38 	 3953 	 False
# HMGB2.hg38 	 6465 	 False
# HMGN3.hg38 	 12410 	 False
# HMGXB4.hg38 	 38209 	 False
# HNRNPH1.hg38 	 2720 	 False
# HNRNPK.hg38 	 42147 	 False
# HNRNPL.hg38 	 36487 	 False
# HNRNPLL.hg38 	 30413 	 False
# HNRNPUL1.hg38 	 3564 	 False
# HOXA10.hg38 	 416 	 True
# HOXA13.hg38 	 163 	 True
# HOXA7.hg38 	 201 	 True
# HOXB5.hg38 	 34 	 True
# HOXB6.hg38 	 683 	 True
# HOXB7.hg38 	 165 	 True
# HOXB8.hg38 	 115 	 True
# HOXC11.hg38 	 124 	 True
# HOXC13.hg38 	 234 	 True
# HOXD11.hg38 	 165 	 True
# HOXD4.hg38 	 27 	 True
# HOXD9.hg38 	 21 	 True
# HSD17B8.hg38 	 1328 	 False
# HSF4.hg38 	 83 	 True
# ID1.hg38 	 6515 	 False
# ID2.hg38 	 3244 	 False
# ID3.hg38 	 8895 	 False
# ID4.hg38 	 95 	 False
# IGF1R.hg38 	 125 	 False
# IGLV5-37.hg38 	 6917 	 False
# ILF3.hg38 	 14403 	 False
# ILK.hg38 	 368 	 False
# ING2.hg38 	 2 	 False
# ING5.hg38 	 2 	 False
# INO80.hg38 	 104644 	 False
# INSM2.hg38 	 3644 	 False
# INSR.hg38 	 4896 	 False
# INTS11.hg38 	 366522 	 False
# INTS12.hg38 	 17204 	 False
# INTS13.hg38 	 60079 	 False
# INTS3.hg38 	 12487 	 False
# IRF8.hg38 	 22 	 True
# IRX2.hg38 	 831 	 True
# IRX3.hg38 	 61 	 True
# IRX5.hg38 	 37 	 True
# ISL2.hg38 	 19 	 True
# IVNS1ABP.hg38 	 29589 	 False
# JARID2.hg38 	 27228 	 False
# JMJD6.hg38 	 54918 	 False
# KAT2A.hg38 	 400 	 False
# KAT2B.hg38 	 15746 	 False
# KAT5.hg38 	 1008 	 False
# KAT7.hg38 	 25076 	 False
# KAT8.hg38 	 33373 	 False
# KDM1A.hg38 	 449194 	 False
# KDM1B.hg38 	 1971 	 False
# KDM3A.hg38 	 22698 	 False
# KDM3B.hg38 	 14945 	 False
# KDM4A.hg38 	 68092 	 False
# KDM4B.hg38 	 6363 	 False
# KDM4C.hg38 	 18541 	 False
# KDM5A.hg38 	 48624 	 False
# KDM5B.hg38 	 195158 	 False
# KDM5C.hg38 	 20051 	 False
# KDM5D.hg38 	 8250 	 False
# KDM6A.hg38 	 95649 	 False
# KDM6B.hg38 	 21042 	 False
# KDM7A.hg38 	 4451 	 False
# KLF14.hg38 	 324 	 True
# KMT2B.hg38 	 265695 	 False
# KMT2C.hg38 	 53853 	 False
# KMT2D.hg38 	 8161 	 False
# L3MBTL2.hg38 	 26433 	 False
# L3MBTL4.hg38 	 9429 	 False
# LAMB3.hg38 	 955 	 False
# LAMTOR5.hg38 	 238 	 False
# LARP7.hg38 	 48536 	 False
# LDB1.hg38 	 15881 	 False
# LEO1.hg38 	 73381 	 False
# LHX3.hg38 	 132 	 True
# LHX4.hg38 	 442 	 True
# LHX5.hg38 	 33 	 True
# LHX6.hg38 	 13 	 True
# LMNA.hg38 	 426827 	 False
# LMNB1.hg38 	 399187 	 False
# LMNB2.hg38 	 70 	 False
# LMO1.hg38 	 39027 	 False
# LMTK3.hg38 	 3853 	 False
# LMX1B.hg38 	 215 	 True
# MAML1.hg38 	 3127 	 False
# MAP1LC3B.hg38 	 6 	 False
# MAP2K1.hg38 	 50 	 False
# MAPK14.hg38 	 49828 	 False
# MAPK3.hg38 	 399 	 False
# MBD1.hg38 	 6962 	 False
# MBD3.hg38 	 26996 	 False
# MBD3L2.hg38 	 13 	 False
# MBD4.hg38 	 418734 	 False
# MBL2.hg38 	 213311 	 False
# MBTD1.hg38 	 4021 	 False
# MBTPS2.hg38 	 12833 	 False
# MCM2.hg38 	 160 	 False
# MCM3.hg38 	 890 	 False
# MCM5.hg38 	 108 	 False
# MCM7.hg38 	 151712 	 False
# MCRS1.hg38 	 52 	 False
# MDM2.hg38 	 22 	 False
# ME1.hg38 	 205925 	 False
# ME3.hg38 	 177465 	 False
# MED12.hg38 	 80636 	 False
# MED26.hg38 	 5009 	 False
# MEN1.hg38 	 15989 	 False
# MEOX2.hg38 	 33 	 True
# METTL14.hg38 	 3008 	 False
# METTL3.hg38 	 3753 	 False
# MIER1.hg38 	 2182 	 False
# MIER2.hg38 	 15627 	 False
# MIER3.hg38 	 36539 	 False
# MLLT1.hg38 	 39496 	 False
# MLLT3.hg38 	 21085 	 False
# MLXIP.hg38 	 562 	 True
# MNX1.hg38 	 186 	 True
# MORC2.hg38 	 3611 	 False
# MPHOSPH8.hg38 	 117 	 False
# MSX2.hg38 	 36 	 True
# MTA1.hg38 	 6090 	 False
# MTA2.hg38 	 42282 	 False
# MTA3.hg38 	 15773 	 False
# MTHFD1.hg38 	 124 	 False
# MTOR.hg38 	 85524 	 False
# MUC22.hg38 	 8880 	 False
# MXD3.hg38 	 20304 	 False
# MXD4.hg38 	 13636 	 False
# MYBL1.hg38 	 560 	 True
# MYF6.hg38 	 252 	 True
# MYH11.hg38 	 10584 	 False
# MYOCD.hg38 	 5733 	 False
# NAB2.hg38 	 2026 	 False
# NBN.hg38 	 14199 	 False
# NCAPH2.hg38 	 28501 	 False
# NCOA1.hg38 	 211796 	 False
# NCOA2.hg38 	 5092 	 False
# NCOA3.hg38 	 54671 	 False
# NCOA4.hg38 	 7831 	 False
# NCOA6.hg38 	 491 	 False
# NCOR1.hg38 	 216681 	 False
# NCOR2.hg38 	 101996 	 False
# NELFA.hg38 	 25128 	 False
# NELFE.hg38 	 108664 	 False
# NEUROD2.hg38 	 178 	 True
# NEUROG3.hg38 	 41 	 True
# NFATC4.hg38 	 45 	 True
# NFE2L3.hg38 	 296 	 True
# NFKBIA.hg38 	 14300 	 False
# NFKBIZ.hg38 	 24217 	 False
# NFRKB.hg38 	 10593 	 False
# NFXL1.hg38 	 2332 	 False
# NHLH1.hg38 	 19 	 True
# NIPBL.hg38 	 195591 	 False
# NKX2-8.hg38 	 106 	 True
# NKX6-1.hg38 	 982 	 True
# NME2.hg38 	 2028 	 False
# NONO.hg38 	 33548 	 False
# NOTCH1.hg38 	 59518 	 False
# NOTCH3.hg38 	 16849 	 False
# NPAT.hg38 	 273 	 False
# NR0B1.hg38 	 988 	 True
# NR1D1.hg38 	 269 	 True
# NR1I2.hg38 	 663 	 True
# NR2E3.hg38 	 17 	 True
# NR3C2.hg38 	 36 	 True
# NR4A2.hg38 	 50 	 True
# NR5A1.hg38 	 112 	 True
# NSD2.hg38 	 19088 	 False
# NUFIP1.hg38 	 104 	 False
# NUP153.hg38 	 20396 	 False
# NUP98.hg38 	 211438 	 False
# NXF1.hg38 	 7 	 False
# OGG1.hg38 	 108944 	 False
# OR2M7.hg38 	 15921 	 False
# ORC1.hg38 	 18443 	 False
# ORC2.hg38 	 34326 	 False
# OTX1.hg38 	 15 	 True
# OVOL3.hg38 	 1648 	 False
# PADI2.hg38 	 286980 	 False
# PAF1.hg38 	 291 	 False
# PALB2.hg38 	 26935 	 False
# PARP1.hg38 	 192175 	 False
# PAX2.hg38 	 848 	 True
# PAX8.hg38 	 660 	 True
# PBRM1.hg38 	 16 	 False
# PBXIP1.hg38 	 2270 	 False
# PCBP1.hg38 	 23196 	 False
# PCBP2.hg38 	 7825 	 False
# PCF11.hg38 	 35405 	 False
# PCGF1.hg38 	 622 	 False
# PCGF2.hg38 	 24374 	 False
# PCGF5.hg38 	 22 	 False
# PCGF6.hg38 	 79 	 False
# PER1.hg38 	 213 	 False
# PEX2.hg38 	 147285 	 False
# PGBD5.hg38 	 101 	 False
# PHB2.hg38 	 2313 	 False
# PHF2.hg38 	 10139 	 False
# PHF20.hg38 	 2862 	 False
# PHF21A.hg38 	 787 	 False
# PHF5A.hg38 	 39334 	 False
# PHF6.hg38 	 7498 	 False
# PHF8.hg38 	 72267 	 False
# PIAS1.hg38 	 48328 	 False
# PIAS4.hg38 	 456 	 False
# PITX1.hg38 	 422 	 True
# PLRG1.hg38 	 51 	 False
# PML.hg38 	 18592 	 False
# PPARA.hg38 	 177 	 True
# PPARGC1A.hg38 	 279 	 False
# PRDM10.hg38 	 45056 	 False
# PRDM11.hg38 	 9546 	 False
# PRDM2.hg38 	 4 	 False
# PRKCQ.hg38 	 28541 	 False
# PRKDC.hg38 	 1241 	 False
# PRMT1.hg38 	 113503 	 False
# PRMT5.hg38 	 1272 	 False
# PRPF4.hg38 	 6350 	 False
# PSMB5.hg38 	 252 	 False
# PTBP1.hg38 	 22066 	 False
# PTEN.hg38 	 60677 	 False
# PTPRA.hg38 	 913 	 False
# PTTG1.hg38 	 1278 	 False
# PYGO2.hg38 	 15418 	 False
# RAD21.hg38 	 759360 	 False
# RAD51.hg38 	 22239 	 False
# RAG1.hg38 	 2163 	 False
# RAG2.hg38 	 51598 	 False
# RARB.hg38 	 231 	 True
# RAX2.hg38 	 115 	 True
# RB1.hg38 	 36078 	 False
# RBBP5.hg38 	 97189 	 False
# RBFOX2.hg38 	 49002 	 False
# RBL1.hg38 	 92 	 False
# RBL2.hg38 	 11442 	 False
# RBM14.hg38 	 7334 	 False
# RBM15.hg38 	 938 	 False
# RBM17.hg38 	 14 	 False
# RBM22.hg38 	 16284 	 False
# RBM25.hg38 	 56028 	 False
# RBM34.hg38 	 1302 	 False
# RBM39.hg38 	 10757 	 False
# RCOR1.hg38 	 125963 	 False
# RCOR2.hg38 	 30873 	 False
# REPIN1.hg38 	 18 	 False
# RERE.hg38 	 17090 	 False
# RFX7.hg38 	 527 	 True
# RFXANK.hg38 	 13457 	 False
# RING1.hg38 	 372718 	 False
# RLF.hg38 	 470 	 False
# RNF2.hg38 	 309298 	 False
# RNGTT.hg38 	 15633 	 False
# RORA.hg38 	 667 	 True
# RPA1.hg38 	 74 	 False
# RPA2.hg38 	 70 	 False
# RUNX1T1.hg38 	 138833 	 False
# RUVBL1.hg38 	 254 	 False
# RUVBL2.hg38 	 57 	 False
# RYBP.hg38 	 3970 	 False
# SAFB.hg38 	 5277 	 False
# SAFB2.hg38 	 31 	 False
# SALL1.hg38 	 0 	 True
# SALL2.hg38 	 46 	 True
# SALL3.hg38 	 16394 	 False
# SAP130.hg38 	 70102 	 False
# SAP30.hg38 	 85171 	 False
# SCML2.hg38 	 35334 	 False
# SETBP1.hg38 	 526 	 False
# SETD1A.hg38 	 1579 	 False
# SETD7.hg38 	 2793 	 False
# SETX.hg38 	 9425 	 False
# SFMBT1.hg38 	 6298 	 False
# SFPQ.hg38 	 292567 	 False
# SIGMAR1.hg38 	 87 	 False
# SIN3A.hg38 	 253458 	 False
# SIN3B.hg38 	 9690 	 False
# SIPA1.hg38 	 2674 	 False
# SIRT1.hg38 	 135561 	 False
# SIRT3.hg38 	 1803 	 False
# SIRT6.hg38 	 41146 	 False
# SIX4.hg38 	 267 	 True
# SKI.hg38 	 55961 	 False
# SKIL.hg38 	 7603 	 False
# SKP2.hg38 	 933 	 False
# SLC30A9.hg38 	 22616 	 False
# SMAD2.hg38 	 179035 	 False
# SMARCA1.hg38 	 1944 	 False
# SMARCA2.hg38 	 35774 	 False
# SMARCA4.hg38 	 743500 	 False
# SMARCA5.hg38 	 32690 	 False
# SMARCB1.hg38 	 13055 	 False
# SMARCC1.hg38 	 550897 	 False
# SMARCC2.hg38 	 22439 	 False
# SMARCE1.hg38 	 34453 	 False
# SMC1A.hg38 	 127761 	 False
# SMC3.hg38 	 363318 	 False
# SMCHD1.hg38 	 678 	 False
# SMN1.hg38 	 17510 	 False
# SNAI1.hg38 	 842 	 True
# SNAPC2.hg38 	 26 	 False
# SNAPC4.hg38 	 1606 	 False
# SNIP1.hg38 	 1126 	 False
# SNRNP70.hg38 	 501 	 False
# SOD1.hg38 	 11 	 False
# SON.hg38 	 9163 	 False
# SOX11.hg38 	 85 	 True
# SOX15.hg38 	 41 	 True
# SOX3.hg38 	 512 	 True
# SP140.hg38 	 137876 	 False
# SQSTM1.hg38 	 313 	 False
# SRC.hg38 	 31336 	 False
# SRCAP.hg38 	 60812 	 False
# SRPK1.hg38 	 3958 	 False
# SRPK2.hg38 	 2747 	 False
# SRSF3.hg38 	 26454 	 False
# SRSF4.hg38 	 1116 	 False
# SRSF7.hg38 	 206 	 False
# SRSF9.hg38 	 2427 	 False
# SS18-SSX1.hg38 	 5707 	 False
# SS18.hg38 	 275870 	 False
# SSRP1.hg38 	 517927 	 False
# SSU72.hg38 	 51192 	 False
# STAG1.hg38 	 108809 	 False
# STAG2.hg38 	 45418 	 False
# STN1.hg38 	 13 	 False
# SUMO1.hg38 	 2326 	 False
# SUMO2.hg38 	 213892 	 False
# SUPT16H.hg38 	 848 	 False
# SUPT20H.hg38 	 2278 	 False
# SUPT5H.hg38 	 160043 	 False
# SUZ12.hg38 	 508426 	 False
# SVIL.hg38 	 251 	 False
# SYNCRIP.hg38 	 220 	 False
# TAF1.hg38 	 84825 	 False
# TAF12.hg38 	 1 	 False
# TAF15.hg38 	 23378 	 False
# TAF3.hg38 	 9784 	 False
# TAF7.hg38 	 8116 	 False
# TAF9B.hg38 	 886 	 False
# TARDBP.hg38 	 26309 	 False
# TAZ.hg38 	 1346 	 False
# TBL1XR1.hg38 	 34393 	 False
# TBPL1.hg38 	 4512 	 False
# TCFL5.hg38 	 20 	 True
# TCOF1.hg38 	 61 	 False
# TDRD3.hg38 	 15 	 False
# TERF1.hg38 	 3661 	 False
# TERT.hg38 	 512 	 False
# TET2.hg38 	 40131 	 False
# TFAM.hg38 	 77 	 False
# TFCP2.hg38 	 403 	 True
# TFDP2.hg38 	 11 	 True
# TGIF1.hg38 	 4 	 True
# THRA.hg38 	 241 	 True
# THRAP3.hg38 	 112 	 False
# TLE3.hg38 	 80527 	 False
# TOP1.hg38 	 40364 	 False
# TOP2B.hg38 	 2037 	 False
# TOX4.hg38 	 471 	 False
# TP53BP1.hg38 	 40652 	 False
# TRIM22.hg38 	 37104 	 False
# TRIM24.hg38 	 133433 	 False
# TRIM25.hg38 	 11100 	 False
# TRIM28.hg38 	 312535 	 False
# TRIP13.hg38 	 307 	 False
# TSC22D4.hg38 	 14600 	 False
# TSHZ1.hg38 	 1556 	 False
# TUBG1.hg38 	 328 	 False
# U2AF1.hg38 	 7382 	 False
# U2AF2.hg38 	 3955 	 False
# UBE2I.hg38 	 483 	 False
# UBN1.hg38 	 6517 	 False
# UBTF.hg38 	 40207 	 False
# USP7.hg38 	 38862 	 False
# WAPL.hg38 	 1 	 False
# WDHD1.hg38 	 1112 	 False
# WDR5.hg38 	 25615 	 False
# WIZ.hg38 	 186 	 False
# WRN.hg38 	 31 	 False
# WRNIP1.hg38 	 3334 	 False
# XRCC3.hg38 	 74 	 False
# XRCC4.hg38 	 20260 	 False
# XRCC5.hg38 	 47711 	 False
# XRN2.hg38 	 6629 	 False
# YAP1.hg38 	 22443 	 False
# YBX3.hg38 	 207 	 True
# ZA.hg38 	 113 	 False
# ZBED4.hg38 	 383 	 False
# ZBED5.hg38 	 2872 	 False
# ZBTB1.hg38 	 377 	 True
# ZBTB10.hg38 	 3270 	 False
# ZBTB21.hg38 	 6193 	 False
# ZBTB24.hg38 	 13415 	 False
# ZBTB25.hg38 	 17997 	 False
# ZBTB39.hg38 	 1 	 False
# ZBTB40.hg38 	 24849 	 False
# ZBTB49.hg38 	 68 	 True
# ZBTB5.hg38 	 1534 	 False
# ZBTB8A.hg38 	 12410 	 False
# ZC3H11A.hg38 	 6997 	 False
# ZC3H8.hg38 	 48690 	 False
# ZFAT.hg38 	 10327 	 False
# ZFP36.hg38 	 47097 	 False
# ZFP36L1.hg38 	 295 	 False
# ZFP37.hg38 	 73 	 False
# ZFP82.hg38 	 826 	 True
# ZFP91.hg38 	 5323 	 False
# ZGPAT.hg38 	 18607 	 False
# ZHX2.hg38 	 55128 	 False
# ZIK1.hg38 	 33 	 True
# ZKSCAN8.hg38 	 26028 	 False
# ZMIZ1.hg38 	 9640 	 False
# ZMYM2.hg38 	 370 	 False
# ZMYM3.hg38 	 43342 	 False
# ZMYND11.hg38 	 477 	 False
# ZMYND8.hg38 	 12234 	 False
# ZNF112.hg38 	 178 	 False
# ZNF114.hg38 	 83 	 True
# ZNF132.hg38 	 25 	 True
# ZNF136.hg38 	 473 	 True
# ZNF138.hg38 	 52 	 False
# ZNF155.hg38 	 35 	 False
# ZNF16.hg38 	 847 	 True
# ZNF165.hg38 	 175 	 False
# ZNF169.hg38 	 195 	 True
# ZNF174.hg38 	 11 	 True
# ZNF19.hg38 	 88 	 True
# ZNF195.hg38 	 16 	 False
# ZNF202.hg38 	 929 	 True
# ZNF207.hg38 	 9463 	 False
# ZNF211.hg38 	 289 	 True
# ZNF214.hg38 	 380 	 True
# ZNF221.hg38 	 7 	 False
# ZNF223.hg38 	 730 	 True
# ZNF23.hg38 	 168 	 True
# ZNF239.hg38 	 303 	 False
# ZNF248.hg38 	 184 	 True
# ZNF26.hg38 	 912 	 True
# ZNF280C.hg38 	 11 	 False
# ZNF280D.hg38 	 10131 	 False
# ZNF292.hg38 	 496 	 False
# ZNF300.hg38 	 116 	 True
# ZNF302.hg38 	 85 	 True
# ZNF311.hg38 	 48 	 True
# ZNF318.hg38 	 5560 	 False
# ZNF354A.hg38 	 808 	 True
# ZNF354B.hg38 	 500 	 True
# ZNF354C.hg38 	 160 	 True
# ZNF362.hg38 	 4648 	 False
# ZNF366.hg38 	 59369 	 False
# ZNF391.hg38 	 1801 	 False
# ZNF395.hg38 	 2897 	 False
# ZNF404.hg38 	 327 	 False
# ZNF407.hg38 	 3830 	 False
# ZNF416.hg38 	 61 	 True
# ZNF418.hg38 	 924 	 True
# ZNF419.hg38 	 306 	 True
# ZNF426.hg38 	 7298 	 False
# ZNF445.hg38 	 39 	 True
# ZNF454.hg38 	 370 	 True
# ZNF473.hg38 	 14 	 False
# ZNF48.hg38 	 25857 	 False
# ZNF488.hg38 	 396 	 False
# ZNF491.hg38 	 89 	 False
# ZNF493.hg38 	 57 	 False
# ZNF501.hg38 	 29 	 True
# ZNF502.hg38 	 626 	 True
# ZNF507.hg38 	 4816 	 False
# ZNF510.hg38 	 610 	 False
# ZNF511.hg38 	 15732 	 False
# ZNF512.hg38 	 4356 	 False
# ZNF512B.hg38 	 980 	 False
# ZNF514.hg38 	 68 	 False
# ZNF518A.hg38 	 9887 	 False
# ZNF521.hg38 	 23 	 True
# ZNF524.hg38 	 415 	 True
# ZNF530.hg38 	 262 	 True
# ZNF532.hg38 	 478 	 False
# ZNF544.hg38 	 125 	 False
# ZNF548.hg38 	 625 	 True
# ZNF560.hg38 	 332 	 False
# ZNF571.hg38 	 19 	 True
# ZNF577.hg38 	 5436 	 False
# ZNF579.hg38 	 2273 	 False
# ZNF581.hg38 	 390 	 True
# ZNF582.hg38 	 671 	 True
# ZNF585B.hg38 	 4406 	 False
# ZNF592.hg38 	 7794 	 False
# ZNF595.hg38 	 638 	 True
# ZNF600.hg38 	 17525 	 False
# ZNF618.hg38 	 2539 	 False
# ZNF621.hg38 	 30 	 True
# ZNF622.hg38 	 67 	 False
# ZNF623.hg38 	 8291 	 False
# ZNF624.hg38 	 32 	 False
# ZNF626.hg38 	 146 	 True
# ZNF629.hg38 	 14935 	 False
# ZNF639.hg38 	 42877 	 False
# ZNF644.hg38 	 45867 	 False
# ZNF645.hg38 	 7 	 False
# ZNF654.hg38 	 24769 	 False
# ZNF658.hg38 	 17 	 True
# ZNF662.hg38 	 22 	 True
# ZNF667.hg38 	 466 	 True
# ZNF669.hg38 	 812 	 True
# ZNF670.hg38 	 22 	 False
# ZNF687.hg38 	 11290 	 False
# ZNF704.hg38 	 72 	 True
# ZNF707.hg38 	 764 	 True
# ZNF747.hg38 	 8 	 False
# ZNF774.hg38 	 290 	 True
# ZNF776.hg38 	 15 	 True
# ZNF777.hg38 	 81 	 True
# ZNF781.hg38 	 6830 	 False
# ZNF784.hg38 	 990 	 True
# ZNF785.hg38 	 98 	 True
# ZNF83.hg38 	 33621 	 False
# ZNF830.hg38 	 366 	 False
# ZNF837.hg38 	 14 	 False
# ZNF843.hg38 	 5900 	 False
# ZNF92.hg38 	 22963 	 False
# ZSCAN18.hg38 	 86 	 False
# ZSCAN2.hg38 	 4612 	 False
# ZSCAN21.hg38 	 1541 	 False
# ZSCAN23.hg38 	 257 	 True
# ZSCAN26.hg38 	 80 	 True
# ZSCAN5A.hg38 	 72835 	 False
# ZSCAN5B.hg38 	 372 	 False
# ZSCAN5DP.hg38 	 4418 	 False
# ZXDB.hg38 	 7339 	 False
# ZXDC.hg38 	 21044 	 False
# c-myc.hg38 	 217 	 False
# p65.hg38 	 33508 	 False
# top2beta.hg38 	 49 	 False

# %%
output_df = pd.DataFrame(output)
output_df['name']= output_df[0]+'.'+output_df[1].astype(str)
output_df['path'] = output_df[2]
output_df['number_of_sites'] = output_df[1]
output_df['path'] = [os.path.abspath(item) for item in output_df['path']]
print(len(output_df[0].unique()))
output_df = output_df[['name','path','number_of_sites']]
# Out:
# 566

# %%
output_df.head()
# Out:
#              name                                               path  \
# 0   AHR.hg38.1000  /fh/fast/ha_g/user/adoebley/projects/griffin_r...
# 1   AHR.hg38.5000  /fh/fast/ha_g/user/adoebley/projects/griffin_r...
# 2  AHR.hg38.10000  /fh/fast/ha_g/user/adoebley/projects/griffin_r...
# 3  AHR.hg38.20000  /fh/fast/ha_g/user/adoebley/projects/griffin_r...
# 4  AHR.hg38.30000  /fh/fast/ha_g/user/adoebley/projects/griffin_r...
#
#    number_of_sites
# 0             1000
# 1             5000
# 2            10000
# 3            20000
# 4            30000

# %%
with open (out_yaml, 'w+' )as f:
    f.write('site_lists:\n  ')
    f.write('\n  '.join([': '.join(item) for item in output_df[['name','path']].values]))

# %%
for i in number_of_sites:
    with open (str(i)+'_'+output_name+'.yaml', 'w+' )as f:
        current_df = output_df[output_df['number_of_sites']==i]
        f.write('site_lists:\n  ')
        f.write('\n  '.join([': '.join(item) for item in current_df[['name','path']].values]))
        print(i,len(current_df))
# Out:
# 1000 566
# 5000 446
# 10000 377
# 20000 316
# 30000 270
# 50000 202
